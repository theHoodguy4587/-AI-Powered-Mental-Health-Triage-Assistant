# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/raw/train.csv')
test = pd.read_csv('../data/raw/test.csv')
val = pd.read_csv('../data/raw/val.csv')

# %%
train.shape
# Out:
# (34823, 2)

# %%
test.shape
# Out:
# (10883, 2)

# %%
val.shape
# Out:
# (8706, 2)

# %%
train['label'].value_counts()
# Out:
# label
# self.depression      11940
# self.SuicideWatch     6550
# self.Anxiety          6136
# self.offmychest       5265
# self.bipolar          4932
# Name: count, dtype: int64

# %%
train.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# ## Distribution of labels in training set

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(x='label', data=train)    
plt.xlabel('label')
plt.ylabel('count')
plt.title('Distribution of labels in training set')
plt.show()

# %%
train['length']= train['text'].apply(len)
train['length'].describe()
# Out:
# count    34823.000000
# mean       936.172558
# std       1252.262622
# min         39.000000
# 25%        207.500000
# 50%        564.000000
# 75%       1180.000000
# max      36729.000000
# Name: length, dtype: float64

# %% [markdown]
# ## Distribution of text length in training set

# %%
plt.figure(figsize=(10,6))
sns.histplot(train['length'], bins=50, kde=True)
plt.xlabel('length')
plt.ylabel('count')
plt.title('Distribution of text length in training set')
# Out:
# Text(0.5, 1.0, 'Distribution of text length in training set')

# %% [markdown]
# ## Word Cloud of Training Texts

# %%
import wordcloud
from wordcloud import WordCloud


text = ' '.join(train['text'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10,6))
plt.imshow(np.array(wordcloud.to_image()), interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Training Texts')
plt.show()

# %%
train
# Out:
#                                                     text              label  \
# 0      wanting to skip or postpone my exam my exam is...       self.Anxiety
# 1      Do other bipolar folks have problems with subs...       self.bipolar
# 2      Wanted to share some revelations I just had to...    self.depression
# 3      I feel deader than dead. I find that I don't h...  self.SuicideWatch
# 4      I'm pretty sure my friends suicidal what do I ...  self.SuicideWatch
# ...                                                  ...                ...
# 34818  Think its time to return. Heart pacing hand st...    self.depression
# 34819  I lost my best friend 5 months ago to suicide ...  self.SuicideWatch
# 34820  I want to share my diagnosis with someone rece...       self.bipolar
# 34821  Anyone else pretend they’re having a conversat...    self.depression
# 34822  I'm not strong enough to live and I never will...  self.SuicideWatch
#
#        length
# 0         396
# 1         829
# 2        5400
# 3        2439
# 4         548
# ...       ...
# 34818     805
# 34819    1326
# 34820    1922
# 34821     274
# 34822     452
#
# [34823 rows x 3 columns]

# %%
train.isnull().sum()
# Out:
# text      0
# label     0
# length    0
# dtype: int64
